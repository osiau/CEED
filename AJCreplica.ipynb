# %%
#import packages 
import io #for input and output operations
import requests #to get() the PDFs or url
from PyPDF2 import PdfReader #package for reading info from the PDFs
import pdfplumber #package for reading info from the PDFs
import re #regular expressions allows a user to search for strings
from itertools import chain # used to merge ranges
import pandas as pd
import numpy as np
from sklearn import preprocessing #for text cleaning
import matplotlib.pyplot as plt #for plotting
from sklearn.feature_extraction.text import TfidfVectorizer #for text representation
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
#model testing
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Uploading & Clean-Up ##
# - Upload BIL & IRA lists from whitehouse.gov
# - Clean data to make it readable and transform to mimic AJC database

# %% [markdown]
# #### BIL data ####

# %%
url = f'https://www.whitehouse.gov/wp-content/uploads/2023/06/20230615-build-gov-csv.csv'  #BIL page: https://www.whitehouse.gov/build/guidebook/
BILraw = pd.read_csv(url)

BILraw.head()
# Out:
#                                         Program Name             Category  \
# 0                                 Regulatory Program           Resilience
# 1  Water-Related Environmental Infrastructure Ass...           Resilience
# 2        Major Rehabilitation for Rivers and Harbors  Ports and Waterways
# 3                          Inland Waterways Projects  Ports and Waterways
# 4  Continuing Authorities Program (Under Flood Co...           Resilience
#
#                                        Agency Name  \
# 0  Department of Defense – Army Corps of Engineers
# 1  Department of Defense – Army Corps of Engineers
# 2  Department of Defense – Army Corps of Engineers
# 3  Department of Defense – Army Corps of Engineers
# 4  Department of Defense – Army Corps of Engineers
#
#                         Bureau Name  Funding Amount  \
# 0  Corps of Engineers – Civil Works    $160,000,000
# 1  Corps of Engineers – Civil Works    $200,000,000
# 2  Corps of Engineers – Civil Works  $1,500,000,000
# 3  Corps of Engineers – Civil Works  $2,500,000,000
# 4  Corps of Engineers – Civil Works    $465,000,000
#
#                                 Funding Amount Notes  \
# 0                                                NaN
# 1                                                NaN
# 2  Including for $250 million for Small, Remote, ...
# 3                                                NaN
# 4                                                NaN
#
#      Period of Availability Funding Mechanism New Program (Yes/No)  \
# 0               2022 - 2026    Direct Federal                   No
# 1  Available until expended    Direct Federal                   No
# 2  Available until expended    Direct Federal                   No
# 3  Available until expended    Direct Federal                   No
# 4  Available until expended    Direct Federal                   No
#
#                                           Recipients  \
# 0                  Army Corps permitting activities.
# 1  In partnership with State, local, and Tribal g...
# 2  In partnership with port authorities, the Army...
# 3  The Army Corps will use this funding to constr...
# 4  The Army Corps will use this funding to plan, ...
#
#                                  Program Description  \
# 0  Provides funds to administer the laws and regu...
# 1  The program funds engineering and construction...
# 2  Funds the construction of authorized coastal n...
# 3  Funds the replacement and expansion of inland ...
# 4  Funds eligible small Army Corps projects, incl...
#
#                                        Eligible Uses Next Program Milestone  \
# 0   Labor and related expenses for Army Corps staff.       To be determined
# 1   Authorized environmental infrastructure projects       To be determined
# 2  Federal commercial navigation projects on coas...       To be determined
# 3  Federal commercial navigation projects on inla...       To be determined
# 4  A variety of water resources projects which mu...       To be determined
#
#   sam.gov link     Statutory Location  \
# 0          NaN  Division J, Title III
# 1          NaN  Division J, Title III
# 2          NaN  Division J, Title III
# 3          NaN  Division J, Title III
# 4          NaN  Division J, Title III
#
#                       Federal Cost Share Requirement
# 0  No cost share requirement. Applicants can elec...
# 1  In general, unless otherwise specified in law,...
# 2  In general, unless otherwise specified in law,...
# 3  In general, unless otherwise specified in law,...
# 4  In general, unless otherwise specified in law:...

# %%
BILclean = BILraw
BILclean.rename(columns={'Program Name':'program','Agency Name':'agency', 'Bureau Name':'bureau', 'Funding Amount':'funding_amt', 'Funding Amount Notes':'funding_amt_notes','Funding Mechanism':'funding_type', 'Recipients':'eligibility', 'Program Description':'description', 'Eligible Uses':'eligible_uses', 'Next Program Milestone':'next_milestone','sam.gov link':'link'}, inplace=True)
BILclean.head()
# Out:
#                                              program             Category  \
# 0                                 Regulatory Program           Resilience
# 1  Water-Related Environmental Infrastructure Ass...           Resilience
# 2        Major Rehabilitation for Rivers and Harbors  Ports and Waterways
# 3                          Inland Waterways Projects  Ports and Waterways
# 4  Continuing Authorities Program (Under Flood Co...           Resilience
#
#                                             agency  \
# 0  Department of Defense – Army Corps of Engineers
# 1  Department of Defense – Army Corps of Engineers
# 2  Department of Defense – Army Corps of Engineers
# 3  Department of Defense – Army Corps of Engineers
# 4  Department of Defense – Army Corps of Engineers
#
#                              bureau     funding_amt  \
# 0  Corps of Engineers – Civil Works    $160,000,000
# 1  Corps of Engineers – Civil Works    $200,000,000
# 2  Corps of Engineers – Civil Works  $1,500,000,000
# 3  Corps of Engineers – Civil Works  $2,500,000,000
# 4  Corps of Engineers – Civil Works    $465,000,000
#
#                                    funding_amt_notes  \
# 0                                                NaN
# 1                                                NaN
# 2  Including for $250 million for Small, Remote, ...
# 3                                                NaN
# 4                                                NaN
#
#      Period of Availability    funding_type New Program (Yes/No)  \
# 0               2022 - 2026  Direct Federal                   No
# 1  Available until expended  Direct Federal                   No
# 2  Available until expended  Direct Federal                   No
# 3  Available until expended  Direct Federal                   No
# 4  Available until expended  Direct Federal                   No
#
#                                          eligibility  \
# 0                  Army Corps permitting activities.
# 1  In partnership with State, local, and Tribal g...
# 2  In partnership with port authorities, the Army...
# 3  The Army Corps will use this funding to constr...
# 4  The Army Corps will use this funding to plan, ...
#
#                                          description  \
# 0  Provides funds to administer the laws and regu...
# 1  The program funds engineering and construction...
# 2  Funds the construction of authorized coastal n...
# 3  Funds the replacement and expansion of inland ...
# 4  Funds eligible small Army Corps projects, incl...
#
#                                        eligible_uses    next_milestone link  \
# 0   Labor and related expenses for Army Corps staff.  To be determined  NaN
# 1   Authorized environmental infrastructure projects  To be determined  NaN
# 2  Federal commercial navigation projects on coas...  To be determined  NaN
# 3  Federal commercial navigation projects on inla...  To be determined  NaN
# 4  A variety of water resources projects which mu...  To be determined  NaN
#
#       Statutory Location                     Federal Cost Share Requirement
# 0  Division J, Title III  No cost share requirement. Applicants can elec...
# 1  Division J, Title III  In general, unless otherwise specified in law,...
# 2  Division J, Title III  In general, unless otherwise specified in law,...
# 3  Division J, Title III  In general, unless otherwise specified in law,...
# 4  Division J, Title III  In general, unless otherwise specified in law:...

# %%
BILclean.drop(columns=['Category', 'Statutory Location'], axis=1, inplace=True) #drop unnecessary info
dbColumns = {'category':0, 'category_label':1, 'agencyId':2, 'eligibilityId':3 ,'application':15 , 'pollution':17, 'technical':18}
for column, position in dbColumns.items(): 
    BILclean.insert(position, column, np.nan)

BILclean.head()
# Out:
#    category  category_label  agencyId  eligibilityId  \
# 0       NaN             NaN       NaN            NaN
# 1       NaN             NaN       NaN            NaN
# 2       NaN             NaN       NaN            NaN
# 3       NaN             NaN       NaN            NaN
# 4       NaN             NaN       NaN            NaN
#
#                                              program  \
# 0                                 Regulatory Program
# 1  Water-Related Environmental Infrastructure Ass...
# 2        Major Rehabilitation for Rivers and Harbors
# 3                          Inland Waterways Projects
# 4  Continuing Authorities Program (Under Flood Co...
#
#                                             agency  \
# 0  Department of Defense – Army Corps of Engineers
# 1  Department of Defense – Army Corps of Engineers
# 2  Department of Defense – Army Corps of Engineers
# 3  Department of Defense – Army Corps of Engineers
# 4  Department of Defense – Army Corps of Engineers
#
#                              bureau     funding_amt  \
# 0  Corps of Engineers – Civil Works    $160,000,000
# 1  Corps of Engineers – Civil Works    $200,000,000
# 2  Corps of Engineers – Civil Works  $1,500,000,000
# 3  Corps of Engineers – Civil Works  $2,500,000,000
# 4  Corps of Engineers – Civil Works    $465,000,000
#
#                                    funding_amt_notes  \
# 0                                                NaN
# 1                                                NaN
# 2  Including for $250 million for Small, Remote, ...
# 3                                                NaN
# 4                                                NaN
#
#      Period of Availability  ... New Program (Yes/No)  \
# 0               2022 - 2026  ...                   No
# 1  Available until expended  ...                   No
# 2  Available until expended  ...                   No
# 3  Available until expended  ...                   No
# 4  Available until expended  ...                   No
#
#                                          eligibility  \
# 0                  Army Corps permitting activities.
# 1  In partnership with State, local, and Tribal g...
# 2  In partnership with port authorities, the Army...
# 3  The Army Corps will use this funding to constr...
# 4  The Army Corps will use this funding to plan, ...
#
#                                          description  \
# 0  Provides funds to administer the laws and regu...
# 1  The program funds engineering and construction...
# 2  Funds the construction of authorized coastal n...
# 3  Funds the replacement and expansion of inland ...
# 4  Funds eligible small Army Corps projects, incl...
#
#                                        eligible_uses application  \
# 0   Labor and related expenses for Army Corps staff.         NaN
# 1   Authorized environmental infrastructure projects         NaN
# 2  Federal commercial navigation projects on coas...         NaN
# 3  Federal commercial navigation projects on inla...         NaN
# 4  A variety of water resources projects which mu...         NaN
#
#      next_milestone pollution  technical  link  \
# 0  To be determined       NaN        NaN   NaN
# 1  To be determined       NaN        NaN   NaN
# 2  To be determined       NaN        NaN   NaN
# 3  To be determined       NaN        NaN   NaN
# 4  To be determined       NaN        NaN   NaN
#
#                       Federal Cost Share Requirement
# 0  No cost share requirement. Applicants can elec...
# 1  In general, unless otherwise specified in law,...
# 2  In general, unless otherwise specified in law,...
# 3  In general, unless otherwise specified in law,...
# 4  In general, unless otherwise specified in law:...
#
# [5 rows x 21 columns]

# %%
#agencyId column update!
#-----------------------

#IRAclean['agency'].unique() #get unique values
abbr = {'Department of Transportation': 'dot', 'Department of Defense – Army Corps of Engineers' :'dod-ace', 'General Services Administration':'gsa', 'Department of Homeland Security':'dhs', 'Environmental Protection Agency':'epa', 'Department of Energy':'doe',
        'Department of the Interior':'doi', 'Department of Agriculture':'doa', 'Department of Health and Human Services':'dhhs', 'Department of Commerce':'doc', 'Federal Communications Commission':'fcc', 'Denali Commission':'denali', 'Appalachian Regional Commission':'arc',
       'Delta Regional Authority':'dra', 'Northern Border Regional Commission':'nbrc','Southeast Crescent Regional Commission':'scrc', 'Council on Environmental Quality':'ceq', 'Department of Housing and Urban Development':'hud','U.S. Postal Service':'usps'} #create dictionary of agency abbreviates (how to handle subbranch of dod?)

BILclean['agencyId'] = BILclean['agency'].map(abbr) #map abbreviations to agency names

BILclean.head()
# Out:
#    category  category_label agencyId  eligibilityId  \
# 0       NaN             NaN  dod-ace            NaN
# 1       NaN             NaN  dod-ace            NaN
# 2       NaN             NaN  dod-ace            NaN
# 3       NaN             NaN  dod-ace            NaN
# 4       NaN             NaN  dod-ace            NaN
#
#                                              program  \
# 0                                 Regulatory Program
# 1  Water-Related Environmental Infrastructure Ass...
# 2        Major Rehabilitation for Rivers and Harbors
# 3                          Inland Waterways Projects
# 4  Continuing Authorities Program (Under Flood Co...
#
#                                             agency  \
# 0  Department of Defense – Army Corps of Engineers
# 1  Department of Defense – Army Corps of Engineers
# 2  Department of Defense – Army Corps of Engineers
# 3  Department of Defense – Army Corps of Engineers
# 4  Department of Defense – Army Corps of Engineers
#
#                              bureau     funding_amt  \
# 0  Corps of Engineers – Civil Works    $160,000,000
# 1  Corps of Engineers – Civil Works    $200,000,000
# 2  Corps of Engineers – Civil Works  $1,500,000,000
# 3  Corps of Engineers – Civil Works  $2,500,000,000
# 4  Corps of Engineers – Civil Works    $465,000,000
#
#                                    funding_amt_notes  \
# 0                                                NaN
# 1                                                NaN
# 2  Including for $250 million for Small, Remote, ...
# 3                                                NaN
# 4                                                NaN
#
#      Period of Availability  ... New Program (Yes/No)  \
# 0               2022 - 2026  ...                   No
# 1  Available until expended  ...                   No
# 2  Available until expended  ...                   No
# 3  Available until expended  ...                   No
# 4  Available until expended  ...                   No
#
#                                          eligibility  \
# 0                  Army Corps permitting activities.
# 1  In partnership with State, local, and Tribal g...
# 2  In partnership with port authorities, the Army...
# 3  The Army Corps will use this funding to constr...
# 4  The Army Corps will use this funding to plan, ...
#
#                                          description  \
# 0  Provides funds to administer the laws and regu...
# 1  The program funds engineering and construction...
# 2  Funds the construction of authorized coastal n...
# 3  Funds the replacement and expansion of inland ...
# 4  Funds eligible small Army Corps projects, incl...
#
#                                        eligible_uses application  \
# 0   Labor and related expenses for Army Corps staff.         NaN
# 1   Authorized environmental infrastructure projects         NaN
# 2  Federal commercial navigation projects on coas...         NaN
# 3  Federal commercial navigation projects on inla...         NaN
# 4  A variety of water resources projects which mu...         NaN
#
#      next_milestone pollution  technical  link  \
# 0  To be determined       NaN        NaN   NaN
# 1  To be determined       NaN        NaN   NaN
# 2  To be determined       NaN        NaN   NaN
# 3  To be determined       NaN        NaN   NaN
# 4  To be determined       NaN        NaN   NaN
#
#                       Federal Cost Share Requirement
# 0  No cost share requirement. Applicants can elec...
# 1  In general, unless otherwise specified in law,...
# 2  In general, unless otherwise specified in law,...
# 3  In general, unless otherwise specified in law,...
# 4  In general, unless otherwise specified in law:...
#
# [5 rows x 21 columns]

# %%
#eligibilityId column update
#---------------------------
#eligibility ID dictionary 
eligID = {'tribes':'.tribal', 'tribal':'.tribal', 'tribe':'.tribal',
          'states':'.stateGov', 'state':'.stateGov',
          'nonprofits':'.ngo', 'nongovernmental':'.ngo', 'non-profit':'.ngo',
          'local':'.localGov','town': '.localGov', 'townships': '.localGov','cities': '.localGov','counties': '.localGov','county': '.localGov',
          'community':'.communitygroup',
          'university':'.ed', 'education':'.ed', 'school':'.ed', 'academia':'.ed', 'higher-ed':'.ed', 'college':'.ed', 'colleges': '.ed', 'universities':'.ed',
          'agricultural':'.agricultural',
          'owner':'.indiv', 'corporations':'.indiv', 'companies':'.indiv', 'business':'.indiv', 'businesses':'.indiv', 'firm':'.indiv', 'commercial':'.indiv'} #what's the difference between stategov, localgov, and statescountiescities, how to code .statesCountiesCities and .indiv 

def addEligibilityId(pddf,dict):
    eligKeys = list(dict.keys()) # lists out all the keys of the key value pairs
    pddf['eligibility'] = pddf['eligibility'].fillna('N/A') #fill nan with N/A 


    for index, row in pddf.iterrows(): #goes through each row of the dataframe
        pattern = r'\b({})\b'.format('|'.join(map(re.escape, eligKeys)))
        # unique matches
        matches = set(re.findall(pattern, row['eligibility'].lower(), re.IGNORECASE))
        values = {dict[x] for x in matches}
        pddf.loc[index,"eligibilityId"] = ', '.join(values)
        
    return pddf

# %%
addEligibilityId(BILclean,eligID)
BILclean.head()
# Out:
#    category  category_label agencyId                  eligibilityId  \
# 0       NaN             NaN  dod-ace
# 1       NaN             NaN  dod-ace  .stateGov, .tribal, .localGov
# 2       NaN             NaN  dod-ace
# 3       NaN             NaN  dod-ace                         .indiv
# 4       NaN             NaN  dod-ace
#
#                                              program  \
# 0                                 Regulatory Program
# 1  Water-Related Environmental Infrastructure Ass...
# 2        Major Rehabilitation for Rivers and Harbors
# 3                          Inland Waterways Projects
# 4  Continuing Authorities Program (Under Flood Co...
#
#                                             agency  \
# 0  Department of Defense – Army Corps of Engineers
# 1  Department of Defense – Army Corps of Engineers
# 2  Department of Defense – Army Corps of Engineers
# 3  Department of Defense – Army Corps of Engineers
# 4  Department of Defense – Army Corps of Engineers
#
#                              bureau     funding_amt  \
# 0  Corps of Engineers – Civil Works    $160,000,000
# 1  Corps of Engineers – Civil Works    $200,000,000
# 2  Corps of Engineers – Civil Works  $1,500,000,000
# 3  Corps of Engineers – Civil Works  $2,500,000,000
# 4  Corps of Engineers – Civil Works    $465,000,000
#
#                                    funding_amt_notes  \
# 0                                                NaN
# 1                                                NaN
# 2  Including for $250 million for Small, Remote, ...
# 3                                                NaN
# 4                                                NaN
#
#      Period of Availability  ... New Program (Yes/No)  \
# 0               2022 - 2026  ...                   No
# 1  Available until expended  ...                   No
# 2  Available until expended  ...                   No
# 3  Available until expended  ...                   No
# 4  Available until expended  ...                   No
#
#                                          eligibility  \
# 0                  Army Corps permitting activities.
# 1  In partnership with State, local, and Tribal g...
# 2  In partnership with port authorities, the Army...
# 3  The Army Corps will use this funding to constr...
# 4  The Army Corps will use this funding to plan, ...
#
#                                          description  \
# 0  Provides funds to administer the laws and regu...
# 1  The program funds engineering and construction...
# 2  Funds the construction of authorized coastal n...
# 3  Funds the replacement and expansion of inland ...
# 4  Funds eligible small Army Corps projects, incl...
#
#                                        eligible_uses application  \
# 0   Labor and related expenses for Army Corps staff.         NaN
# 1   Authorized environmental infrastructure projects         NaN
# 2  Federal commercial navigation projects on coas...         NaN
# 3  Federal commercial navigation projects on inla...         NaN
# 4  A variety of water resources projects which mu...         NaN
#
#      next_milestone pollution  technical  link  \
# 0  To be determined       NaN        NaN   NaN
# 1  To be determined       NaN        NaN   NaN
# 2  To be determined       NaN        NaN   NaN
# 3  To be determined       NaN        NaN   NaN
# 4  To be determined       NaN        NaN   NaN
#
#                       Federal Cost Share Requirement
# 0  No cost share requirement. Applicants can elec...
# 1  In general, unless otherwise specified in law,...
# 2  In general, unless otherwise specified in law,...
# 3  In general, unless otherwise specified in law,...
# 4  In general, unless otherwise specified in law:...
#
# [5 rows x 21 columns]

# %%
# Remove non AJC formatted columns
columns_to_remove = ['Period of Availability','New Program (Yes/No)','Federal Cost Share Requirement']

# Create a new DataFrame with the dropped columns
BILdropped = pd.DataFrame()
for column in columns_to_remove:
    BILdropped = BILdropped.assign(**{column: BILclean.pop(column)})


BILdropped
# Out:
#        Period of Availability New Program (Yes/No)  \
# 0                 2022 - 2026                   No
# 1    Available until expended                   No
# 2    Available until expended                   No
# 3    Available until expended                   No
# 4    Available until expended                   No
# ..                        ...                  ...
# 377  Available until expended                   No
# 378               2022 - 2026                   No
# 379  Available until expended                   No
# 380  Available until expended                   No
# 381  Available until expended                  NaN
#
#                         Federal Cost Share Requirement
# 0    No cost share requirement. Applicants can elec...
# 1    In general, unless otherwise specified in law,...
# 2    In general, unless otherwise specified in law,...
# 3    In general, unless otherwise specified in law,...
# 4    In general, unless otherwise specified in law:...
# ..                                                 ...
# 377                 No non-Federal cost share required
# 378                 No non-Federal cost share required
# 379  Non-eligible activities include the cost to se...
# 380  Maximum Northern Border Regional Commission sh...
# 381  Maximum Southeast Crescent Regional Commission...
#
# [382 rows x 3 columns]

# %%
BILclean['coverage'] = 'BIL'
BILclean
# Out:
#      category  category_label agencyId  \
# 0         NaN             NaN  dod-ace
# 1         NaN             NaN  dod-ace
# 2         NaN             NaN  dod-ace
# 3         NaN             NaN  dod-ace
# 4         NaN             NaN  dod-ace
# ..        ...             ...      ...
# 377       NaN             NaN      gsa
# 378       NaN             NaN     dhhs
# 379       NaN             NaN     dhhs
# 380       NaN             NaN     nbrc
# 381       NaN             NaN     scrc
#
#                                 eligibilityId  \
# 0
# 1               .stateGov, .tribal, .localGov
# 2
# 3                                      .indiv
# 4
# ..                                        ...
# 377
# 378                        .stateGov, .tribal
# 379                                   .tribal
# 380  .ed, .ngo, .stateGov, .localGov, .tribal
# 381
#
#                                                program  \
# 0                                   Regulatory Program
# 1    Water-Related Environmental Infrastructure Ass...
# 2          Major Rehabilitation for Rivers and Harbors
# 3                            Inland Waterways Projects
# 4    Continuing Authorities Program (Under Flood Co...
# ..                                                 ...
# 377                           Real Property Activities
# 378          Low Income Home Energy Assistance Program
# 379  Indian Health Service Sanitation Facilities Co...
# 380  Northern Border Regional Commission: State Eco...
# 381     Southeast Crescent Regional Commission Funding
#
#                                               agency  \
# 0    Department of Defense – Army Corps of Engineers
# 1    Department of Defense – Army Corps of Engineers
# 2    Department of Defense – Army Corps of Engineers
# 3    Department of Defense – Army Corps of Engineers
# 4    Department of Defense – Army Corps of Engineers
# ..                                               ...
# 377                  General Services Administration
# 378          Department of Health and Human Services
# 379          Department of Health and Human Services
# 380              Northern Border Regional Commission
# 381           Southeast Crescent Regional Commission
#
#                                        bureau     funding_amt  \
# 0            Corps of Engineers – Civil Works    $160,000,000
# 1            Corps of Engineers – Civil Works    $200,000,000
# 2            Corps of Engineers – Civil Works  $1,500,000,000
# 3            Corps of Engineers – Civil Works  $2,500,000,000
# 4            Corps of Engineers – Civil Works    $465,000,000
# ..                                        ...             ...
# 377                  Real Property Activities  $3,418,008,000
# 378  Administration for Children and Families    $500,000,000
# 379                     Indian Health Service  $3,500,000,000
# 380       Northern Border Regional Commission    $150,000,000
# 381    Southeast Crescent Regional Commission      $5,000,000
#
#                                      funding_amt_notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Including for $250 million for Small, Remote, ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 377                                                NaN
# 378                                                NaN
# 379  The law makes $700,000,000 available per year ...
# 380                                                NaN
# 381                                                NaN
#
#                                           funding_type  \
# 0                                       Direct Federal
# 1                                       Direct Federal
# 2                                       Direct Federal
# 3                                       Direct Federal
# 4                                       Direct Federal
# ..                                                 ...
# 377                                     Direct Federal
# 378                                              Grant
# 379  Indian Self-Determination and Education Assist...
# 380                                              Grant
# 381                                                NaN
#
#                                            eligibility  \
# 0                    Army Corps permitting activities.
# 1    In partnership with State, local, and Tribal g...
# 2    In partnership with port authorities, the Army...
# 3    The Army Corps will use this funding to constr...
# 4    The Army Corps will use this funding to plan, ...
# ..                                                 ...
# 377  GSA, Public Buildings Service, Federal Buildin...
# 378  States, Territories, Tribal Governments (Feder...
# 379           Federally recognized Tribal governments.
# 380  States, Counties, Cities / Townships, Special ...
# 381                                                N/A
#
#                                            description  \
# 0    Provides funds to administer the laws and regu...
# 1    The program funds engineering and construction...
# 2    Funds the construction of authorized coastal n...
# 3    Funds the replacement and expansion of inland ...
# 4    Funds eligible small Army Corps projects, incl...
# ..                                                 ...
# 377  Construction and acquisition, and repairs and ...
# 378  The Low-Income Home Energy Assistance Program ...
# 379  To support the Indian Health Service mission, ...
# 380  The Northern Border Regional Commission cataly...
# 381  The Southeast Crescent Regional Commission is ...
#
#                                          eligible_uses  application  \
# 0     Labor and related expenses for Army Corps staff.          NaN
# 1     Authorized environmental infrastructure projects          NaN
# 2    Federal commercial navigation projects on coas...          NaN
# 3    Federal commercial navigation projects on inla...          NaN
# 4    A variety of water resources projects which mu...          NaN
# ..                                                 ...          ...
# 377  Construction and acquisition, and repairs and ...          NaN
# 378  The Low-Income Home Energy Assistance Program ...          NaN
# 379  Provision of domestic and community sanitation...          NaN
# 380  Eligible uses are pending final decisions, but...          NaN
# 381  Eligible uses will be determined at a future d...          NaN
#
#                                         next_milestone  pollution  technical  \
# 0                                     To be determined        NaN        NaN
# 1                                     To be determined        NaN        NaN
# 2                                     To be determined        NaN        NaN
# 3                                     To be determined        NaN        NaN
# 4                                     To be determined        NaN        NaN
# ..                                                 ...        ...        ...
# 377                                   To be determined        NaN        NaN
# 378  First Round of Funding Allocated / Selections ...        NaN        NaN
# 379                                   To be determined        NaN        NaN
# 380            Funding Opportunity Closed in June 2023        NaN        NaN
# 381                                   To be determined        NaN        NaN
#
#                                                   link coverage
# 0                                                  NaN      BIL
# 1                                                  NaN      BIL
# 2                                                  NaN      BIL
# 3                                                  NaN      BIL
# 4                                                  NaN      BIL
# ..                                                 ...      ...
# 377                                                NaN      BIL
# 378  https://sam.gov/fal/808947332b21456999592fc431...      BIL
# 379                                                NaN      BIL
# 380  https://sam.gov/fal/a8976f85173017f257d97bca3f...      BIL
# 381                                                NaN      BIL
#
# [382 rows x 19 columns]

# %% [markdown]
# #### IRA data ####

# %%
url = f'https://www.whitehouse.gov/wp-content/uploads/2022/12/IRA-Guidebook-Funding-Programs.csv' #IRA page: https://www.whitehouse.gov/cleanenergy/inflation-reduction-act-guidebook/
columnsIncluded = ['Agency','Bureau','Program','Program Description','Funding Amount','Funding Mechanism','Period of Availability','Eligible Recipients','Tribal Eligibility?','Eligible Uses','New or Existing Program', 'Cost Share Requirement','SAM.gov Assistance Listing'] #columns tin include from raw data
IRAraw = pd.read_csv(url, usecols=columnsIncluded) #columns excluded include: Statutory Location, Formula Funding, Recent Announcements

IRAraw = IRAraw.head(-2)
IRAraw.head()
# Out:
#                              Agency                              Bureau  \
# 0  Council on Environmental Quality                                 NaN
# 1         Department of Agriculture             Rural Utilities Service
# 2         Department of Agriculture  Rural Business-Cooperative Service
# 3         Department of Agriculture             Rural Utilities Service
# 4         Department of Agriculture                 Farm Service Agency
#
#                                              Program  \
# 0         Environmental and Climate Data Improvement
# 1            Powering Affordable Clean Energy (PACE)
# 2  Biofuel Infrastructure and Agriculture Product...
# 3                 Empowering Rural America (New ERA)
# 4                Assistance for Distressed Borrowers
#
#                                  Program Description   Funding Amount  \
# 0  To improve the quality, availability, and use ...     $32,500,000
# 1  To provide partially forgivable loans to renew...  $1,000,000,000
# 2  To provide grants through the Higher Blend Inf...    $500,000,000
# 3  To fund the construction of electric distribut...  $9,700,000,000
# 4  To expedite assistance to distressed borrowers...  $3,100,000,000
#
#                                    Funding Mechanism  \
# 0                            Direct Federal Spending
# 1                            Loans, Loan Forgiveness
# 2                                             Grants
# 3  Loans, modifications of loans, the cost of loa...
# 4                            Direct Federal Spending
#
#                           Period of Availability  \
# 0  To remain available until September 30, 2026.
# 1  To remain available until September 30, 2031.
# 2  To remain available until September 30, 2031.
# 3  To remain available until September 30, 2031.
# 4  To remain available until September 30, 2031.
#
#                                  Eligible Recipients  \
# 0                            Direct Federal Spending
# 1  Eligible entities that generate electricity fo...
# 2  Transportation fueling facilities including fu...
# 3  Rural electric cooperatives, including e xisti...
# 4                            Direct Federal Spending
#
#                                  Tribal Eligibility?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4  Yes. Tribal governments as well as individual ...
#
#                                        Eligible Uses New or Existing Program  \
# 0                           See program description.                Existing
# 1  Applicants can use PACE funds to finance wind,...                Existing
# 2  (1) Fueling stations, convenience stores, hype...                Existing
# 3  To make energy efficiency improvements to elig...                     New
# 4                            Direct federal spending                     New
#
#                               Cost Share Requirement  \
# 0                                                NaN
# 1  Up to 50%, but may be waived at the discretion...
# 2                                                25%
# 3                       Varies, depending on product
# 4                                                NaN
#
#                           SAM.gov Assistance Listing
# 0                                                NaN
# 1  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 2  https://sam.gov/fal/23ed3d84a46f4e688c6f4223fc...
# 3  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 4                                                NaN

# %%
IRAclean = IRAraw
IRAclean.rename(columns={'Program':'program','Agency':'agency', 'Bureau':'bureau', 'Funding Amount':'funding_amt', 'Funding Amount Notes':'funding_amt_notes','Funding Mechanism':'funding_type', 'Eligible Recipients':'eligibility', 'Program Description':'description', 'Eligible Uses':'eligible_uses', 'Next Program Milestone':'next_milestone','SAM.gov Assistance Listing':'link'}, inplace=True)
IRAclean.head()
# Out:
#                              agency                              bureau  \
# 0  Council on Environmental Quality                                 NaN
# 1         Department of Agriculture             Rural Utilities Service
# 2         Department of Agriculture  Rural Business-Cooperative Service
# 3         Department of Agriculture             Rural Utilities Service
# 4         Department of Agriculture                 Farm Service Agency
#
#                                              program  \
# 0         Environmental and Climate Data Improvement
# 1            Powering Affordable Clean Energy (PACE)
# 2  Biofuel Infrastructure and Agriculture Product...
# 3                 Empowering Rural America (New ERA)
# 4                Assistance for Distressed Borrowers
#
#                                          description      funding_amt  \
# 0  To improve the quality, availability, and use ...     $32,500,000
# 1  To provide partially forgivable loans to renew...  $1,000,000,000
# 2  To provide grants through the Higher Blend Inf...    $500,000,000
# 3  To fund the construction of electric distribut...  $9,700,000,000
# 4  To expedite assistance to distressed borrowers...  $3,100,000,000
#
#                                         funding_type  \
# 0                            Direct Federal Spending
# 1                            Loans, Loan Forgiveness
# 2                                             Grants
# 3  Loans, modifications of loans, the cost of loa...
# 4                            Direct Federal Spending
#
#                           Period of Availability  \
# 0  To remain available until September 30, 2026.
# 1  To remain available until September 30, 2031.
# 2  To remain available until September 30, 2031.
# 3  To remain available until September 30, 2031.
# 4  To remain available until September 30, 2031.
#
#                                          eligibility  \
# 0                            Direct Federal Spending
# 1  Eligible entities that generate electricity fo...
# 2  Transportation fueling facilities including fu...
# 3  Rural electric cooperatives, including e xisti...
# 4                            Direct Federal Spending
#
#                                  Tribal Eligibility?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4  Yes. Tribal governments as well as individual ...
#
#                                        eligible_uses New or Existing Program  \
# 0                           See program description.                Existing
# 1  Applicants can use PACE funds to finance wind,...                Existing
# 2  (1) Fueling stations, convenience stores, hype...                Existing
# 3  To make energy efficiency improvements to elig...                     New
# 4                            Direct federal spending                     New
#
#                               Cost Share Requirement  \
# 0                                                NaN
# 1  Up to 50%, but may be waived at the discretion...
# 2                                                25%
# 3                       Varies, depending on product
# 4                                                NaN
#
#                                                 link
# 0                                                NaN
# 1  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 2  https://sam.gov/fal/23ed3d84a46f4e688c6f4223fc...
# 3  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 4                                                NaN

# %%
dbColumns = {'category':0, 'category_label':1, 'agencyId':2, 'eligibilityId':3 ,'application':15 , 'pollution':17, 'technical':18}
for column, position in dbColumns.items(): 
    IRAclean.insert(position, column, np.nan)

IRAclean.head()
# Out:
#    category  category_label  agencyId  eligibilityId  \
# 0       NaN             NaN       NaN            NaN
# 1       NaN             NaN       NaN            NaN
# 2       NaN             NaN       NaN            NaN
# 3       NaN             NaN       NaN            NaN
# 4       NaN             NaN       NaN            NaN
#
#                              agency                              bureau  \
# 0  Council on Environmental Quality                                 NaN
# 1         Department of Agriculture             Rural Utilities Service
# 2         Department of Agriculture  Rural Business-Cooperative Service
# 3         Department of Agriculture             Rural Utilities Service
# 4         Department of Agriculture                 Farm Service Agency
#
#                                              program  \
# 0         Environmental and Climate Data Improvement
# 1            Powering Affordable Clean Energy (PACE)
# 2  Biofuel Infrastructure and Agriculture Product...
# 3                 Empowering Rural America (New ERA)
# 4                Assistance for Distressed Borrowers
#
#                                          description      funding_amt  \
# 0  To improve the quality, availability, and use ...     $32,500,000
# 1  To provide partially forgivable loans to renew...  $1,000,000,000
# 2  To provide grants through the Higher Blend Inf...    $500,000,000
# 3  To fund the construction of electric distribut...  $9,700,000,000
# 4  To expedite assistance to distressed borrowers...  $3,100,000,000
#
#                                         funding_type  \
# 0                            Direct Federal Spending
# 1                            Loans, Loan Forgiveness
# 2                                             Grants
# 3  Loans, modifications of loans, the cost of loa...
# 4                            Direct Federal Spending
#
#                           Period of Availability  \
# 0  To remain available until September 30, 2026.
# 1  To remain available until September 30, 2031.
# 2  To remain available until September 30, 2031.
# 3  To remain available until September 30, 2031.
# 4  To remain available until September 30, 2031.
#
#                                          eligibility  \
# 0                            Direct Federal Spending
# 1  Eligible entities that generate electricity fo...
# 2  Transportation fueling facilities including fu...
# 3  Rural electric cooperatives, including e xisti...
# 4                            Direct Federal Spending
#
#                                  Tribal Eligibility?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4  Yes. Tribal governments as well as individual ...
#
#                                        eligible_uses New or Existing Program  \
# 0                           See program description.                Existing
# 1  Applicants can use PACE funds to finance wind,...                Existing
# 2  (1) Fueling stations, convenience stores, hype...                Existing
# 3  To make energy efficiency improvements to elig...                     New
# 4                            Direct federal spending                     New
#
#    application                             Cost Share Requirement  pollution  \
# 0          NaN                                                NaN        NaN
# 1          NaN  Up to 50%, but may be waived at the discretion...        NaN
# 2          NaN                                                25%        NaN
# 3          NaN                       Varies, depending on product        NaN
# 4          NaN                                                NaN        NaN
#
#    technical                                               link
# 0        NaN                                                NaN
# 1        NaN  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 2        NaN  https://sam.gov/fal/23ed3d84a46f4e688c6f4223fc...
# 3        NaN  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 4        NaN                                                NaN

# %%
IRAclean['agencyId'] = IRAclean['agency'].map(abbr) #map abbreviations to agency names
addEligibilityId(IRAclean,eligID)
IRAclean.head()
# Out:
#    category  category_label agencyId                     eligibilityId  \
# 0       NaN             NaN      ceq
# 1       NaN             NaN      doa  .indiv, .stateGov, .ngo, .tribal
# 2       NaN             NaN      doa
# 3       NaN             NaN      doa
# 4       NaN             NaN      doa
#
#                              agency                              bureau  \
# 0  Council on Environmental Quality                                 NaN
# 1         Department of Agriculture             Rural Utilities Service
# 2         Department of Agriculture  Rural Business-Cooperative Service
# 3         Department of Agriculture             Rural Utilities Service
# 4         Department of Agriculture                 Farm Service Agency
#
#                                              program  \
# 0         Environmental and Climate Data Improvement
# 1            Powering Affordable Clean Energy (PACE)
# 2  Biofuel Infrastructure and Agriculture Product...
# 3                 Empowering Rural America (New ERA)
# 4                Assistance for Distressed Borrowers
#
#                                          description      funding_amt  \
# 0  To improve the quality, availability, and use ...     $32,500,000
# 1  To provide partially forgivable loans to renew...  $1,000,000,000
# 2  To provide grants through the Higher Blend Inf...    $500,000,000
# 3  To fund the construction of electric distribut...  $9,700,000,000
# 4  To expedite assistance to distressed borrowers...  $3,100,000,000
#
#                                         funding_type  \
# 0                            Direct Federal Spending
# 1                            Loans, Loan Forgiveness
# 2                                             Grants
# 3  Loans, modifications of loans, the cost of loa...
# 4                            Direct Federal Spending
#
#                           Period of Availability  \
# 0  To remain available until September 30, 2026.
# 1  To remain available until September 30, 2031.
# 2  To remain available until September 30, 2031.
# 3  To remain available until September 30, 2031.
# 4  To remain available until September 30, 2031.
#
#                                          eligibility  \
# 0                            Direct Federal Spending
# 1  Eligible entities that generate electricity fo...
# 2  Transportation fueling facilities including fu...
# 3  Rural electric cooperatives, including e xisti...
# 4                            Direct Federal Spending
#
#                                  Tribal Eligibility?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4  Yes. Tribal governments as well as individual ...
#
#                                        eligible_uses New or Existing Program  \
# 0                           See program description.                Existing
# 1  Applicants can use PACE funds to finance wind,...                Existing
# 2  (1) Fueling stations, convenience stores, hype...                Existing
# 3  To make energy efficiency improvements to elig...                     New
# 4                            Direct federal spending                     New
#
#    application                             Cost Share Requirement  pollution  \
# 0          NaN                                                NaN        NaN
# 1          NaN  Up to 50%, but may be waived at the discretion...        NaN
# 2          NaN                                                25%        NaN
# 3          NaN                       Varies, depending on product        NaN
# 4          NaN                                                NaN        NaN
#
#    technical                                               link
# 0        NaN                                                NaN
# 1        NaN  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 2        NaN  https://sam.gov/fal/23ed3d84a46f4e688c6f4223fc...
# 3        NaN  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 4        NaN                                                NaN

# %%
# Remove non AJC formatted columns
columns_to_remove = ['Period of Availability','Tribal Eligibility?','New or Existing Program','Cost Share Requirement']

# Create a new DataFrame with the dropped columns
IRAdropped = pd.DataFrame()
for column in columns_to_remove:
    IRAdropped = IRAdropped.assign(**{column: IRAclean.pop(column)})


IRAdropped
# Out:
#                             Period of Availability  \
# 0    To remain available until September 30, 2026.
# 1    To remain available until September 30, 2031.
# 2    To remain available until September 30, 2031.
# 3    To remain available until September 30, 2031.
# 4    To remain available until September 30, 2031.
# ..                                             ...
# 105   To remain available until September 30, 2031
# 106                     Through September 30, 2031
# 107                     Through September 30, 2026
# 108                     Through September 30, 2026
# 109  To remain available until September 30, 2031.
#
#                                    Tribal Eligibility?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4    Yes. Tribal governments as well as individual ...
# ..                                                 ...
# 105                                                 No
# 106                                                 No
# 107                                                 No
# 108                                                 No
# 109                                                NaN
#
#     New or Existing Program                             Cost Share Requirement
# 0                  Existing                                                NaN
# 1                  Existing  Up to 50%, but may be waived at the discretion...
# 2                  Existing                                                25%
# 3                       New                       Varies, depending on product
# 4                       New                                                NaN
# ..                      ...                                                ...
# 105                     New                                                 No
# 106                Existing                                                NaN
# 107                Existing                                                NaN
# 108                Existing                                                NaN
# 109                     New                                                NaN
#
# [110 rows x 4 columns]

# %%
IRAclean['coverage'] = 'IRA'
IRAclean
# Out:
#      category  category_label agencyId                     eligibilityId  \
# 0         NaN             NaN      ceq
# 1         NaN             NaN      doa  .indiv, .stateGov, .ngo, .tribal
# 2         NaN             NaN      doa
# 3         NaN             NaN      doa
# 4         NaN             NaN      doa
# ..        ...             ...      ...                               ...
# 105       NaN             NaN      epa                         .stateGov
# 106       NaN             NaN      gsa
# 107       NaN             NaN      gsa
# 108       NaN             NaN      gsa
# 109       NaN             NaN     usps
#
#                                agency                              bureau  \
# 0    Council on Environmental Quality                                 NaN
# 1           Department of Agriculture             Rural Utilities Service
# 2           Department of Agriculture  Rural Business-Cooperative Service
# 3           Department of Agriculture             Rural Utilities Service
# 4           Department of Agriculture                 Farm Service Agency
# ..                                ...                                 ...
# 105   Environmental Protection Agency         Office of Air and Radiation
# 106   General Services Administration            Real Property Activities
# 107   General Services Administration            Real Property Activities
# 108   General Services Administration            Real Property Activities
# 109               U.S. Postal Service                                 NaN
#
#                                                program  \
# 0           Environmental and Climate Data Improvement
# 1              Powering Affordable Clean Energy (PACE)
# 2    Biofuel Infrastructure and Agriculture Product...
# 3                   Empowering Rural America (New ERA)
# 4                  Assistance for Distressed Borrowers
# ..                                                 ...
# 105  Funding to Address Air Pollution: Mobile Sourc...
# 106                   Assistance for Federal Buildings
# 107                        Use of Low-Carbon Materials
# 108  General Services Administration Emerging Techn...
# 109                   U.S. Postal Service Clean Fleets
#
#                                            description      funding_amt  \
# 0    To improve the quality, availability, and use ...     $32,500,000
# 1    To provide partially forgivable loans to renew...  $1,000,000,000
# 2    To provide grants through the Higher Blend Inf...    $500,000,000
# 3    To fund the construction of electric distribut...  $9,700,000,000
# 4    To expedite assistance to distressed borrowers...  $3,100,000,000
# ..                                                 ...              ...
# 105  To provide grants to states to adopt and imple...      $5,000,000
# 106  To convert GSA facilities to high-performance ...    $250,000,000
# 107  To acquire and install construction materials ...  $2,150,000,000
# 108  To support emerging and sustainable technologi...    $975,000,000
# 109  To purchase zero-emission delivery vehicles an...  $3,000,000,000
#
#                                           funding_type  \
# 0                              Direct Federal Spending
# 1                              Loans, Loan Forgiveness
# 2                                               Grants
# 3    Loans, modifications of loans, the cost of loa...
# 4                              Direct Federal Spending
# ..                                                 ...
# 105                                             Grants
# 106                            Direct Federal Spending
# 107                            Direct Federal Spending
# 108                            Direct Federal Spending
# 109                            Direct Federal Spending
#
#                                            eligibility  \
# 0                              Direct Federal Spending
# 1    Eligible entities that generate electricity fo...
# 2    Transportation fueling facilities including fu...
# 3    Rural electric cooperatives, including e xisti...
# 4                              Direct Federal Spending
# ..                                                 ...
# 105  States, others TBD. The Clean Air Act defines ...
# 106                            Direct Federal Spending
# 107                            Direct Federal Spending
# 108                            Direct Federal Spending
# 109                            Direct Federal Spending
#
#                                          eligible_uses  application  \
# 0                             See program description.          NaN
# 1    Applicants can use PACE funds to finance wind,...          NaN
# 2    (1) Fueling stations, convenience stores, hype...          NaN
# 3    To make energy efficiency improvements to elig...          NaN
# 4                              Direct federal spending          NaN
# ..                                                 ...          ...
# 105  To provide grants to states covered by section...          NaN
# 106  Measures that improve a building's environment...          NaN
# 107  Providing for the construction and renovation ...          NaN
# 108  Providing for the purchase, installation, and ...          NaN
# 109  To purchase zero-emission delivery vehicles an...          NaN
#
#      pollution  technical                                               link  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 2          NaN        NaN  https://sam.gov/fal/23ed3d84a46f4e688c6f4223fc...
# 3          NaN        NaN  https://sam.gov/fal/779b429f23b04071acc7dcfd9e...
# 4          NaN        NaN                                                NaN
# ..         ...        ...                                                ...
# 105        NaN        NaN                                                TBD
# 106        NaN        NaN                                                NaN
# 107        NaN        NaN                                                NaN
# 108        NaN        NaN                                                NaN
# 109        NaN        NaN                                                NaN
#
#     coverage
# 0        IRA
# 1        IRA
# 2        IRA
# 3        IRA
# 4        IRA
# ..       ...
# 105      IRA
# 106      IRA
# 107      IRA
# 108      IRA
# 109      IRA
#
# [110 rows x 17 columns]

# %% [markdown]
# ## Combined datasets ##

# %%
combined = BILclean.append(IRAclean, ignore_index=True)
combined
# Out:
# C:\Users\unosia\AppData\Local\Temp\ipykernel_17716\3975187263.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = BILclean.append(IRAclean, ignore_index=True)
#      category  category_label agencyId                  eligibilityId  \
# 0         NaN             NaN  dod-ace
# 1         NaN             NaN  dod-ace  .stateGov, .tribal, .localGov
# 2         NaN             NaN  dod-ace
# 3         NaN             NaN  dod-ace                         .indiv
# 4         NaN             NaN  dod-ace
# ..        ...             ...      ...                            ...
# 487       NaN             NaN      epa                      .stateGov
# 488       NaN             NaN      gsa
# 489       NaN             NaN      gsa
# 490       NaN             NaN      gsa
# 491       NaN             NaN     usps
#
#                                                program  \
# 0                                   Regulatory Program
# 1    Water-Related Environmental Infrastructure Ass...
# 2          Major Rehabilitation for Rivers and Harbors
# 3                            Inland Waterways Projects
# 4    Continuing Authorities Program (Under Flood Co...
# ..                                                 ...
# 487  Funding to Address Air Pollution: Mobile Sourc...
# 488                   Assistance for Federal Buildings
# 489                        Use of Low-Carbon Materials
# 490  General Services Administration Emerging Techn...
# 491                   U.S. Postal Service Clean Fleets
#
#                                               agency  \
# 0    Department of Defense – Army Corps of Engineers
# 1    Department of Defense – Army Corps of Engineers
# 2    Department of Defense – Army Corps of Engineers
# 3    Department of Defense – Army Corps of Engineers
# 4    Department of Defense – Army Corps of Engineers
# ..                                               ...
# 487                  Environmental Protection Agency
# 488                  General Services Administration
# 489                  General Services Administration
# 490                  General Services Administration
# 491                              U.S. Postal Service
#
#                                bureau      funding_amt  \
# 0    Corps of Engineers – Civil Works     $160,000,000
# 1    Corps of Engineers – Civil Works     $200,000,000
# 2    Corps of Engineers – Civil Works   $1,500,000,000
# 3    Corps of Engineers – Civil Works   $2,500,000,000
# 4    Corps of Engineers – Civil Works     $465,000,000
# ..                                ...              ...
# 487       Office of Air and Radiation      $5,000,000
# 488          Real Property Activities    $250,000,000
# 489          Real Property Activities  $2,150,000,000
# 490          Real Property Activities    $975,000,000
# 491                               NaN  $3,000,000,000
#
#                                      funding_amt_notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Including for $250 million for Small, Remote, ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 487                                                NaN
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
#
#                 funding_type  \
# 0             Direct Federal
# 1             Direct Federal
# 2             Direct Federal
# 3             Direct Federal
# 4             Direct Federal
# ..                       ...
# 487                   Grants
# 488  Direct Federal Spending
# 489  Direct Federal Spending
# 490  Direct Federal Spending
# 491  Direct Federal Spending
#
#                                            eligibility  \
# 0                    Army Corps permitting activities.
# 1    In partnership with State, local, and Tribal g...
# 2    In partnership with port authorities, the Army...
# 3    The Army Corps will use this funding to constr...
# 4    The Army Corps will use this funding to plan, ...
# ..                                                 ...
# 487  States, others TBD. The Clean Air Act defines ...
# 488                            Direct Federal Spending
# 489                            Direct Federal Spending
# 490                            Direct Federal Spending
# 491                            Direct Federal Spending
#
#                                            description  \
# 0    Provides funds to administer the laws and regu...
# 1    The program funds engineering and construction...
# 2    Funds the construction of authorized coastal n...
# 3    Funds the replacement and expansion of inland ...
# 4    Funds eligible small Army Corps projects, incl...
# ..                                                 ...
# 487  To provide grants to states to adopt and imple...
# 488  To convert GSA facilities to high-performance ...
# 489  To acquire and install construction materials ...
# 490  To support emerging and sustainable technologi...
# 491  To purchase zero-emission delivery vehicles an...
#
#                                          eligible_uses  application  \
# 0     Labor and related expenses for Army Corps staff.          NaN
# 1     Authorized environmental infrastructure projects          NaN
# 2    Federal commercial navigation projects on coas...          NaN
# 3    Federal commercial navigation projects on inla...          NaN
# 4    A variety of water resources projects which mu...          NaN
# ..                                                 ...          ...
# 487  To provide grants to states covered by section...          NaN
# 488  Measures that improve a building's environment...          NaN
# 489  Providing for the construction and renovation ...          NaN
# 490  Providing for the purchase, installation, and ...          NaN
# 491  To purchase zero-emission delivery vehicles an...          NaN
#
#        next_milestone  pollution  technical link coverage
# 0    To be determined        NaN        NaN  NaN      BIL
# 1    To be determined        NaN        NaN  NaN      BIL
# 2    To be determined        NaN        NaN  NaN      BIL
# 3    To be determined        NaN        NaN  NaN      BIL
# 4    To be determined        NaN        NaN  NaN      BIL
# ..                ...        ...        ...  ...      ...
# 487               NaN        NaN        NaN  TBD      IRA
# 488               NaN        NaN        NaN  NaN      IRA
# 489               NaN        NaN        NaN  NaN      IRA
# 490               NaN        NaN        NaN  NaN      IRA
# 491               NaN        NaN        NaN  NaN      IRA
#
# [492 rows x 19 columns]

# %% [markdown]
# #### NLP Multiclass Text Classificaiton ####

# %%
#NLP Topic Classfication - automatically analyze text and then assign a set of predefined tags or categories based on its context
# Going to start with importing example classification data from 'A Just Climate' db and preprocessing/cleaning original url: https://docs.google.com/spreadsheets/d/1rUi4ZM8Zvo_hwnh8tSbH1QgurEWUr-u73gtXTINBs7I/edit#gid=781618991
SHEET_ID = '1rUi4ZM8Zvo_hwnh8tSbH1QgurEWUr-u73gtXTINBs7I'
SHEET_GID = '781618991'

url = f'https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv&gid={SHEET_GID}' #SHEET_NAME did not work
ajcRaw = pd.read_csv(url)

ajcRaw.head()
# Out:
#          category                      category_label agencyId  \
# 0       workforce  Training and workforce development      arc
# 1       workforce  Training and workforce development      arc
# 2       workforce  Training and workforce development      arc
# 3       workforce  Training and workforce development   denali
# 4  transportation                Clean transportation      doe
#
#                          eligibilityId  \
# 0          .statesCountiesCities, .ngo
# 1          .statesCountiesCities, .ngo
# 2          .statesCountiesCities, .ngo
# 3  .statesCountiesCities, .tribal, .ed
# 4                                  NaN
#
#                                              program  \
# 0  Appalachian Area Development: Allocations to A...
# 1  Appalachian Area Development: Community Capaci...
# 2  Appalachian Area Development: Regional Multist...
# 3                                  Denali Commission
# 4         Vehicles Technologies Office: Clean Cities
#
#                             agency  \
# 0  Appalachian Regional Commission
# 1  Appalachian Regional Commission
# 2  Appalachian Regional Commission
# 3                Denali Commission
# 4        U.S. Department of Energy
#
#                                              bureau   funding_amt  \
# 0                   Appalachian Regional Commission  $100,000,000
# 1                   Appalachian Regional Commission   $10,000,000
# 2                   Appalachian Regional Commission   $80,000,000
# 3                                 Denali Commission   $67,750,000
# 4  Office of Energy Efficiency and Renewable Energy           NaN
#
#   funding_amt_notes                          funding_type  \
# 0               NaN  Grants and/or cooperative agreements
# 1               NaN  Grants and/or cooperative agreements
# 2               NaN  Grants and/or cooperative agreements
# 3               NaN                                Grants
# 4               NaN                                   NaN
#
#                        funding_bill  \
# 0                               0.1
# 1                              0.01
# 2                              0.08
# 3                             0.068
# 4  Subject to yearly appropriations
#
#                                          eligibility  \
# 0  States, local governments, and nonprofits both...
# 1  States, local governments, and nonprofits both...
# 2  States, local governments, and nonprofits both...
# 3  States, counties, cities, townships, special d...
# 4            Depends on specific funding opportunity
#
#                                          description  \
# 0  The program provides Area Base Development Pro...
# 1  The program builds capacity throughout Appalac...
# 2  The program provides support for multistate re...
# 3                                                TBD
# 4  The program facilitates national coordination ...
#
#                                        eligible_uses  \
# 0  Projects to support the Appalachian Regional C...
# 1  Projects to support the Appalachian Regional C...
# 2  Projects to support the Appalachian Regional C...
# 3  To be determined, but may include job training...
# 4  Projects to implement alternative fuels and en...
#
#                                       next_milestone application  \
# 0  The notice of funding opportunity was released...         Yes
# 1  The notice of funding opportunity was released...         Yes
# 2  The notice of funding opportunity was released...         Yes
# 3  The notice of funding opportunity was released...         Yes
# 4  Concept papers were due by 5:00 p.m. ET on Aug...         Yes
#
#                                                 link pollution technical
# 0  https://www.arc.gov/state_partner_role/state-p...        No        No
# 1  https://energycommunities.gov/funding-opportun...        No       Yes
# 2  https://energycommunities.gov/funding-opportun...        No        No
# 3                     https://www.denali.gov/grants/        No       Yes
# 4  https://cleancities.energy.gov/funding-opportu...        No        No

# %%
#Preprocessing & Cleaning 

ajcDf = ajcRaw[['category', 'description']] #only choose necessary columns category and description
ajcDf['category'] = ajcDf['category'].str.strip()
ajcDf = ajcDf[(ajcDf['description'].notnull()) & (ajcDf['description'] != 'TBD') & (ajcDf['category'].notna())] #only include rows that have a value in the description column and don't have TBD as a description

ajcDf = ajcDf[(ajcDf['category'] != 'transportation workforce')] #EXCLUDE FOR NOW BUT FIGURE OUT HOW TO SEPARATE LATER

le = preprocessing.LabelEncoder() #create label encoder instance 
#MAY BE NECESSARY TO USE ONE HOT ENCODER INSTEAD because as it stands these labels are ranked not categorical so 'the average of climate and workforce could be transportation' but try both to see!

ajcDf['label'] = le.fit_transform(ajcDf['category']) #use fit_transform to label and create new column with label --- could also use onehotencoder but since the result is binary(0&1) but eliminates ordinality 

catToLab = dict(zip(sorted(set(ajcDf['category'])), sorted(set(ajcDf['label'])))) #create a dictionary of category keys and corresponding label values

#Text Processing - make text readable to algorithm
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(ajcDf.description).toarray()
labels = ajcDf.label
features.shape

X_train, X_test, y_train, y_test = train_test_split(ajcDf['description'], ajcDf['category'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

#apply model to new data
X_train, X_test, y_train, y_test = train_test_split(ajcDf['description'], ajcDf['category'], test_size=0.33, random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
model = LogisticRegression(random_state=0).fit(X_train_tfidf, y_train)
# Convert a collection of text documents to a vector of term/token counts. 
cntVectData = count_vect.transform(combined['description'])

#RUN Prediction
combined['category'] = model.predict(cntVectData)


#update category_label column

webLabel = {'climate':'Climate Change', 'energy':'Clean Energy and Energy Efficiency','housing':'Affordable and sustainable housing','pollution':'Remediation and reduction of legacy pollution','transportation':'Clean Transportation','workforce':'Training and workforce development','water':'Critical clean water and wastewater infrastructure'} #create dictionary of agency abbreviates (how to handle subbranch of dod?)
combined['category_label'] = combined['category'].map(webLabel) #map abbreviations to agency names
combined
# Out:
# C:\Users\unosia\AppData\Local\Temp\ipykernel_17716\3514309377.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ajcDf['category'] = ajcDf['category'].str.strip()
#            category                                     category_label  \
# 0         pollution      Remediation and reduction of legacy pollution
# 1             water  Critical clean water and wastewater infrastruc...
# 2             water  Critical clean water and wastewater infrastruc...
# 3             water  Critical clean water and wastewater infrastruc...
# 4             water  Critical clean water and wastewater infrastruc...
# ..              ...                                                ...
# 487       pollution      Remediation and reduction of legacy pollution
# 488          energy                 Clean Energy and Energy Efficiency
# 489       pollution      Remediation and reduction of legacy pollution
# 490       pollution      Remediation and reduction of legacy pollution
# 491  transportation                               Clean Transportation
#
#     agencyId                  eligibilityId  \
# 0    dod-ace
# 1    dod-ace  .stateGov, .tribal, .localGov
# 2    dod-ace
# 3    dod-ace                         .indiv
# 4    dod-ace
# ..       ...                            ...
# 487      epa                      .stateGov
# 488      gsa
# 489      gsa
# 490      gsa
# 491     usps
#
#                                                program  \
# 0                                   Regulatory Program
# 1    Water-Related Environmental Infrastructure Ass...
# 2          Major Rehabilitation for Rivers and Harbors
# 3                            Inland Waterways Projects
# 4    Continuing Authorities Program (Under Flood Co...
# ..                                                 ...
# 487  Funding to Address Air Pollution: Mobile Sourc...
# 488                   Assistance for Federal Buildings
# 489                        Use of Low-Carbon Materials
# 490  General Services Administration Emerging Techn...
# 491                   U.S. Postal Service Clean Fleets
#
#                                               agency  \
# 0    Department of Defense – Army Corps of Engineers
# 1    Department of Defense – Army Corps of Engineers
# 2    Department of Defense – Army Corps of Engineers
# 3    Department of Defense – Army Corps of Engineers
# 4    Department of Defense – Army Corps of Engineers
# ..                                               ...
# 487                  Environmental Protection Agency
# 488                  General Services Administration
# 489                  General Services Administration
# 490                  General Services Administration
# 491                              U.S. Postal Service
#
#                                bureau      funding_amt  \
# 0    Corps of Engineers – Civil Works     $160,000,000
# 1    Corps of Engineers – Civil Works     $200,000,000
# 2    Corps of Engineers – Civil Works   $1,500,000,000
# 3    Corps of Engineers – Civil Works   $2,500,000,000
# 4    Corps of Engineers – Civil Works     $465,000,000
# ..                                ...              ...
# 487       Office of Air and Radiation      $5,000,000
# 488          Real Property Activities    $250,000,000
# 489          Real Property Activities  $2,150,000,000
# 490          Real Property Activities    $975,000,000
# 491                               NaN  $3,000,000,000
#
#                                      funding_amt_notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Including for $250 million for Small, Remote, ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 487                                                NaN
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
#
#                 funding_type  \
# 0             Direct Federal
# 1             Direct Federal
# 2             Direct Federal
# 3             Direct Federal
# 4             Direct Federal
# ..                       ...
# 487                   Grants
# 488  Direct Federal Spending
# 489  Direct Federal Spending
# 490  Direct Federal Spending
# 491  Direct Federal Spending
#
#                                            eligibility  \
# 0                    Army Corps permitting activities.
# 1    In partnership with State, local, and Tribal g...
# 2    In partnership with port authorities, the Army...
# 3    The Army Corps will use this funding to constr...
# 4    The Army Corps will use this funding to plan, ...
# ..                                                 ...
# 487  States, others TBD. The Clean Air Act defines ...
# 488                            Direct Federal Spending
# 489                            Direct Federal Spending
# 490                            Direct Federal Spending
# 491                            Direct Federal Spending
#
#                                            description  \
# 0    Provides funds to administer the laws and regu...
# 1    The program funds engineering and construction...
# 2    Funds the construction of authorized coastal n...
# 3    Funds the replacement and expansion of inland ...
# 4    Funds eligible small Army Corps projects, incl...
# ..                                                 ...
# 487  To provide grants to states to adopt and imple...
# 488  To convert GSA facilities to high-performance ...
# 489  To acquire and install construction materials ...
# 490  To support emerging and sustainable technologi...
# 491  To purchase zero-emission delivery vehicles an...
#
#                                          eligible_uses  application  \
# 0     Labor and related expenses for Army Corps staff.          NaN
# 1     Authorized environmental infrastructure projects          NaN
# 2    Federal commercial navigation projects on coas...          NaN
# 3    Federal commercial navigation projects on inla...          NaN
# 4    A variety of water resources projects which mu...          NaN
# ..                                                 ...          ...
# 487  To provide grants to states covered by section...          NaN
# 488  Measures that improve a building's environment...          NaN
# 489  Providing for the construction and renovation ...          NaN
# 490  Providing for the purchase, installation, and ...          NaN
# 491  To purchase zero-emission delivery vehicles an...          NaN
#
#        next_milestone  pollution  technical link coverage
# 0    To be determined        NaN        NaN  NaN      BIL
# 1    To be determined        NaN        NaN  NaN      BIL
# 2    To be determined        NaN        NaN  NaN      BIL
# 3    To be determined        NaN        NaN  NaN      BIL
# 4    To be determined        NaN        NaN  NaN      BIL
# ..                ...        ...        ...  ...      ...
# 487               NaN        NaN        NaN  TBD      IRA
# 488               NaN        NaN        NaN  NaN      IRA
# 489               NaN        NaN        NaN  NaN      IRA
# 490               NaN        NaN        NaN  NaN      IRA
# 491               NaN        NaN        NaN  NaN      IRA
#
# [492 rows x 19 columns]

# %% [markdown]
# ## Missing Links ##
# - Links that are missing not links that are TBD

# %%
combined['link']=combined['link'].astype('str')

# %%
def linkSearch(query):
    try:
        from googlesearch import search
    except ImportError:
        print("No module named 'google' found")
 

    results = []
    for j in search(query, tld="co.in", num=6, stop=6, pause=2):
        results.append(j)

    return results

#links = linkSearch("Department of Transportation National Federal Highway Administration Highway Performance Program grant application")

#join agency column and program column and grant application into query for every row
for index, row in combined.iterrows():
    agencyName = row['agency']
    bureauName = row['bureau']
    programName = row['program']

    query = agencyName+bureauName+programName+' grant application'
    
    
    if row['link'] == 'nan':
#after set link equal to first result in list
        firstLink = linkSearch(query)
        combined.loc[index,"link"] = firstLink[0]

combined

# %% [markdown]
# ## To-Do & Updates ##
# - Column positions
# - One to many dictionary for eligibility id
# - what to do about links that dont have a sam.gov link?
# - Might be better to add IRA data before text classification?
# - can instantiate dataframe order upon read-in as well using read_csv
# - Ask if Recent Announcements in IRA data is useful?
# - What to do with columns that don't overlap between the two? -maybe put into separate dataframe for now so it doesn't upset replicability
# - Only include Justice 40 covered programs or just add a column for distinction?
# - TODO: join two data sets, text classification, pollution & technical columns, justice 40 covered programs
# - links that are missing were replaced with the first Google search query
