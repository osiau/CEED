# %%
import pandas as pd 
import numpy as np

j40 = pd.read_csv('J40covered.csv')
rep = pd.read_csv('AJCspreadsheet_replica.csv', usecols = ['agency','program','bureau'])

j40
# Out:
#                                         agency  \
# 0    U.S. Army Corps of Engineers (Army Corps)
# 1    U.S. Army Corps of Engineers (Army Corps)
# 2    U.S. Army Corps of Engineers (Army Corps)
# 3    U.S. Army Corps of Engineers (Army Corps)
# 4    U.S. Army Corps of Engineers (Army Corps)
# ..                                         ...
# 463                National Science Foundation
# 464                National Science Foundation
# 465            Appalachian Regional Commission
# 466                   Delta Regional Authority
# 467                          Denali Commission
#
#                                                program
# 0         Aquatic Ecosystem Restoration – Construction
# 1       Aquatic Ecosystem Restoration – Investigations
# 2     Flood and Storm Damage Reduction Program – Co...
# 3     Flood and Storm Damage Reduction Program – In...
# 4                       Continuing Authorities Program
# ..                                                 ...
# 463               Coastlines and People (COPE) program
# 464               Smart & Connected Communities (S&CC)
# 465             Appalachian Regional Commission Grants
# 466                    Delta Regional Authority Grants
# 467                           Denali Commission Grants
#
# [468 rows x 2 columns]

# %%
rep = rep.drop_duplicates()
rep
# Out:
#                                                program  \
# 0                 National Highway Performance Program
# 1           Surface Transportation Block Grant Program
# 2                               Bridge Formula Program
# 3    Tribal Transportation Facility Bridges (Bridge...
# 4    Congestion Mitigation and Air Quality Improvem...
# ..                                                 ...
# 337                                       Gulf Hypoxia
# 338  Solid Waste Infrastructure for Recycling Infra...
# 339  Reduce, Reuse, Recycling Education and Outreac...
# 340                        Battery Labeling Guidelines
# 341                   Battery Recycling Best Practices
#
#                               agency                           bureau
# 0       Department of Transportation   Federal Highway Administration
# 1       Department of Transportation   Federal Highway Administration
# 2       Department of Transportation   Federal Highway Administration
# 3       Department of Transportation   Federal Highway Administration
# 4       Department of Transportation   Federal Highway Administration
# ..                               ...                              ...
# 337  Environmental Protection Agency  Environmental Protection Agency
# 338  Environmental Protection Agency  Environmental Protection Agency
# 339  Environmental Protection Agency  Environmental Protection Agency
# 340  Environmental Protection Agency  Environmental Protection Agency
# 341  Environmental Protection Agency  Environmental Protection Agency
#
# [333 rows x 3 columns]

# %%
from thefuzz import process
import difflib

def fuzzy_merge(df1, df2, left_on, right_on, how='inner', cutoff=0.6):
    df_other= df2.copy()
    df_other[left_on] = [get_closest_match(x, df1[left_on], cutoff) 
                         for x in df_other[right_on]]
    return df1.merge(df_other, on=left_on, suffixes=('_left', '_right'), how=how)

def get_closest_match(x, other, cutoff):
    matches = difflib.get_close_matches(x, other, cutoff=cutoff)
    return matches[0] if matches else None

mergedDf = fuzzy_merge(rep, j40, left_on='program', right_on='program', how='left')

#Should it be merged on the left or the right?
mergedDf = mergedDf.drop_duplicates().reset_index(drop=True)
mergedDf
# Out:
#                                                program  \
# 0                 National Highway Performance Program
# 1           Surface Transportation Block Grant Program
# 2                               Bridge Formula Program
# 3    Tribal Transportation Facility Bridges (Bridge...
# 4    Congestion Mitigation and Air Quality Improvem...
# ..                                                 ...
# 353                                       Gulf Hypoxia
# 354  Solid Waste Infrastructure for Recycling Infra...
# 355  Reduce, Reuse, Recycling Education and Outreac...
# 356                        Battery Labeling Guidelines
# 357                   Battery Recycling Best Practices
#
#                          agency_left                           bureau  \
# 0       Department of Transportation   Federal Highway Administration
# 1       Department of Transportation   Federal Highway Administration
# 2       Department of Transportation   Federal Highway Administration
# 3       Department of Transportation   Federal Highway Administration
# 4       Department of Transportation   Federal Highway Administration
# ..                               ...                              ...
# 353  Environmental Protection Agency  Environmental Protection Agency
# 354  Environmental Protection Agency  Environmental Protection Agency
# 355  Environmental Protection Agency  Environmental Protection Agency
# 356  Environmental Protection Agency  Environmental Protection Agency
# 357  Environmental Protection Agency  Environmental Protection Agency
#
#                         agency_right
# 0                                NaN
# 1       Department of Transportation
# 2                                NaN
# 3       Department of Transportation
# 4       Department of Transportation
# ..                               ...
# 353  Environmental Protection Agency
# 354  Environmental Protection Agency
# 355  Environmental Protection Agency
# 356                              NaN
# 357                              NaN
#
# [358 rows x 4 columns]

# %%
mergedDf['J40coveredY_N'] = np.where(mergedDf['agency_right'].isnull(), 'No', 'Yes')
mergedDf = mergedDf.rename(columns={'agency_left': 'agency'})
mergedDf.drop('agency_right', axis=1, inplace=True)
mergedDf
# Out:
#                                                program  \
# 0                 National Highway Performance Program
# 1           Surface Transportation Block Grant Program
# 2                               Bridge Formula Program
# 3    Tribal Transportation Facility Bridges (Bridge...
# 4    Congestion Mitigation and Air Quality Improvem...
# ..                                                 ...
# 353                                       Gulf Hypoxia
# 354  Solid Waste Infrastructure for Recycling Infra...
# 355  Reduce, Reuse, Recycling Education and Outreac...
# 356                        Battery Labeling Guidelines
# 357                   Battery Recycling Best Practices
#
#                               agency                           bureau  \
# 0       Department of Transportation   Federal Highway Administration
# 1       Department of Transportation   Federal Highway Administration
# 2       Department of Transportation   Federal Highway Administration
# 3       Department of Transportation   Federal Highway Administration
# 4       Department of Transportation   Federal Highway Administration
# ..                               ...                              ...
# 353  Environmental Protection Agency  Environmental Protection Agency
# 354  Environmental Protection Agency  Environmental Protection Agency
# 355  Environmental Protection Agency  Environmental Protection Agency
# 356  Environmental Protection Agency  Environmental Protection Agency
# 357  Environmental Protection Agency  Environmental Protection Agency
#
#     J40coveredY_N
# 0              No
# 1             Yes
# 2              No
# 3             Yes
# 4             Yes
# ..            ...
# 353           Yes
# 354           Yes
# 355           Yes
# 356            No
# 357            No
#
# [358 rows x 4 columns]

# %%
#final results - all BIL programs that are J40 covered yes-no
mergedDf = mergedDf.drop_duplicates()
mergedDf
# Out:
#                                                program  \
# 0                 National Highway Performance Program
# 1           Surface Transportation Block Grant Program
# 2                               Bridge Formula Program
# 3    Tribal Transportation Facility Bridges (Bridge...
# 4    Congestion Mitigation and Air Quality Improvem...
# ..                                                 ...
# 353                                       Gulf Hypoxia
# 354  Solid Waste Infrastructure for Recycling Infra...
# 355  Reduce, Reuse, Recycling Education and Outreac...
# 356                        Battery Labeling Guidelines
# 357                   Battery Recycling Best Practices
#
#                               agency                           bureau  \
# 0       Department of Transportation   Federal Highway Administration
# 1       Department of Transportation   Federal Highway Administration
# 2       Department of Transportation   Federal Highway Administration
# 3       Department of Transportation   Federal Highway Administration
# 4       Department of Transportation   Federal Highway Administration
# ..                               ...                              ...
# 353  Environmental Protection Agency  Environmental Protection Agency
# 354  Environmental Protection Agency  Environmental Protection Agency
# 355  Environmental Protection Agency  Environmental Protection Agency
# 356  Environmental Protection Agency  Environmental Protection Agency
# 357  Environmental Protection Agency  Environmental Protection Agency
#
#     J40coveredY_N
# 0              No
# 1             Yes
# 2              No
# 3             Yes
# 4             Yes
# ..            ...
# 353           Yes
# 354           Yes
# 355           Yes
# 356            No
# 357            No
#
# [333 rows x 4 columns]

# %% [markdown]
# #### To Do ####
# - need to do the reverse, J40 programs that are BIL and IRA.
